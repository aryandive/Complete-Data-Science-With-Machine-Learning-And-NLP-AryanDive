# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World")

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
a = int(input("Enter the user input: "))
# Out:
# Enter the user input:  5

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
a = int(input("Enter your number: "))

if a < 0:       
    print("The number is negative")
elif a == 0:
    print("The number is zero")
else:
    print("The number is positive")
# Out:
# Enter your number:  -2
# The number is negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
a = int(input("Enter your number: "))
b = int(input("Enter your number: "))
c = int(input("Enter your number: "))

if a > b and a > c:
    print(f"{a} is the bigger number")
elif b > c and b > a:
    print(f"{b} is the bigger number")
elif c > b and c > a:
    print(f"{c} is the bigger number")
else:
    print("all the nubers are equal")
# Out:
# Enter your number:  6
# Enter your number:  8
# Enter your number:  9
# 9 is the bigger number

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
# a = int(input("Enter your number: "))

# if a > 0:
#     print(a*(a-1))
# else:
#     print("Please input a valid number")
    
# return n*(n-1) The return statement only makes sense inside functions (from stack overflow)

## my solution after refering the solution where I found that Krish sir dif the unknown with factorial(n) and here n is unknown

def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
        
a = int(input("Enter your number: "))
print(f'The factorial of the no. {a} is the no. {factorial(a)}') ## I was stuck here I wrote it as factorial and pass the unknow 'n' rather that the variable
# Out:
# Enter your number:  5
# The factorial of the no.5 is the no.120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
var = 5
print(var, type(var))

float = 5.5
print(float, type(float))

string = "string"
print(string, type(string))

boolean = True
print(boolean, type(boolean))
# Out:
# 5 <class 'int'>
# 5.5 <class 'float'>
# string <class 'str'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = int(input("Enter your number: "))
b = int(input("Enter your number: "))

print(f"Before swaping the numbers are {a} and {b}")

# we have to define temp

# def temp():
#     a = temp
#     temp = b

#     return a, b

# function_swap()

## my solution after refering the solution
a, b = b, a
print(f"After swap: a = {a}, b = {b}")
# Out:
# Enter your number:  6
# Enter your number:  6
# Before swaping the numbers are 6 and 6
# After swap: a = 6, b = 6

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
a = int(input("Enter your number: "))


b = a*9/5 + 32
print(f"{a} Degree Celsius is equal to {b} Fahrenheit")
# Out:
# Enter your number:  5
# 5 Degree Celsius is equal to 41.0 Fahrenheit

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here

str1 = "Hello "
str2 = "World"

print("The concatenate of the two strings is:", str1 + str2)
# Out:
# The concatenate of the two strings is: Hello World

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
# a = input("Enter your data: ")

# print(type(a))

# Solution
var = 10.5
if isinstance(var, float):
    print(f"{var} is a float")
else:
    print(f"{var} is not a float")
# Out:
# Enter your data:  5
# <class 'str'>

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
a = int(input("Enter your 1st number: "))
b = int(input("Enter your 2nd number: "))

print(a+b)
print(a-b)
print(a/b)
print(a*b)
# Out:
# Enter your 1st number:  3
# Enter your 2nd number:  5
# 8
# -2
# 0.6
# 15

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
a = int(input("Enter your 1st number: "))
b = int(input("Enter your 2nd number: "))

if a > b:
    print(f"{a} is the bigger number")
    print(f"{a} and {b} are not the equal number")
elif b > a:
    print(f"{b} is the bigger number")
    print(f"{a} and {b} are not the equal number")
elif a == b:
    print(f"{a} and {b} are the equal number")
else:
    print("Put a valid number")
# Out:
# Enter your 1st number:  5
# Enter your 2nd number:  6
# 6 is the bigger number
# 5 and 6 are not the equal number

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a = True
b = False

print(f"True and False: {a and b}")
print(f"True or False: {a or b}")
print(f"not True: {not a}")

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
a = int(input("Enter your number: "))
print("The square number is:", a*a)
# Out:
# Enter your number:  5
# The square number is: 25

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
a = int(input("Enter your number: "))

if a % 2 == 0:
    print("The number is a Even:", a)
else:
    print("The number is a Odd number", a)
# Out:
# Enter your number:  2
# The number is Even 2

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
n = int(input("Enter a number: "))
sum_n = (n * (n + 1)) // 2
print(f"The sum of the first {n} natural numbers is {sum_n}")
# Out:
# Enter a number:  5
# The sum of the first 5 natural numbers is 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
a = int(input("Enter your year: "))

if a % 4 == 0:
    print("The year is leap year")
else:
    print("The year is not leap year")
# Out:
# Enter your year:  2026
# The year is not leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Solution
string = input("Enter a string: ")
reversed_string = string[::-1]
print(f"The reversed string is: {reversed_string}")
# Out:
# Enter your year:  hello

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Solution
string = input("Enter a string: ")
if string == string[::-1]:
    print(f"{string} is a palindrome.")
else:
    print(f"{string} is not a palindrome.")
# Out:
# This is a Palindrom

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Solution
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# [2, 4, 5, 1, 3]
